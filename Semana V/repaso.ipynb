# %%
import numpy as np

# %%
mat100x100 = np.random.randint(256, size=(100, 100))

filas, columnas = mat100x100.shape

# %%
print(filas, columnas)
# Out:
# 100 100

# %%
for camar in range(filas):
    for god in range(columnas):
        mat100x100[camar, god] += 10

mat100x100
# Out:
# array([[ 92, 101, 136, ..., 236, 189, 274],
#        [207, 198, 171, ...,  90,  46, 184],
#        [152, 245, 207, ..., 158,  95,  67],
#        ...,
#        [162, 209,  29, ..., 253, 100, 146],
#        [107,  95, 239, ..., 257, 128, 235],
#        [ 95, 214, 136, ..., 218,  92,  32]], shape=(100, 100))

# %% [markdown]
# ---

# %%
import matplotlib.pyplot as plt

# %%
tralalero = plt.imread("/Users/miguelcamargorojas/Downloads/tralalero.avif")

# %%
plt.imshow(tralalero)
plt.show()

# %%
tenis_der = tralalero[410:550, 100:290]
plt.imshow(tenis_der)
plt.show()

# %% [markdown]
# ---

# %%
# Aislar el rojo

tenis_rojo = tenis_der.copy()

# apagar canal G y B

tenis_rojo[:, :, (1, 2)] = 0

plt.imshow(tenis_rojo)
plt.show()
