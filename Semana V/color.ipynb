# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
imagen = plt.imread('/Users/miguelcamargorojas/iCloud Drive (Archive)/Documents/UP/PDI-Ago-dic24/images/baboon.jpg')
plt.imshow(imagen)
plt.show()

# %%
imagen.shape
# Out:
# (512, 512, 3)

# %%
canal_r = imagen[:, :, 0]

# %%
filas, columnas = canal_r.shape

# %%
# Contar cuántas veces aparece el valor 200 en el canal_r
contador = 0
for fila in range(filas):
    for columna in range(columnas):
        if canal_r[fila, columna] == 200:
            contador += 1

print('Aparece', contador, 'veces el valor 200')
# Out:
# Aparece 828 veces el valor 200

# %%
# Contar cuántas veces aparece un valor par en el canal_r
contador = 0
for fila in range(filas):
    for columna in range(columnas):
        if canal_r[fila, columna] % 2 == 0:
            contador += 1

print('Aparece', contador, 'veces un valor par')
# Out:
# Aparece 130535 veces un valor par
