# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# ---
# # MATRICES

# %%
# matriz 3x3
matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
    ]

# %%
# fi-co
matrix[1][0]
# Out:
# 4

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
type(matrix)
# Out:
# list

# %%
dir(matrix)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
# Dot-notation (.)

matrix_np = np.array(matrix)

# %%
type(matrix_np)
# Out:
# numpy.ndarray

# %%
dir(matrix_np)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_function__',
#  '__array_interface__',
#  '__array_namespace__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__buffer__',
#  '__class__',
#  '__class_getitem__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__divmod__',
#  '__dlpack__',
#  '__dlpack_device__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
# ...

# %%
# Matriz de 1920x1080, todos los elementos son 1's
mat_ones = np.ones((1920, 1080), np.uint8) # tipo de dato: entero sin singno 8 bits

# %%
mat_zeros = np.zeros((1920, 1080), np.uint8)

# %%
mat_ones.shape
# Out:
# (1920, 1080)

# %%
1920*1080
# Out:
# 2073600

# %%
mat_ones.size
# Out:
# 2073600

# %%
mat_ones.dtype
# Out:
# dtype('uint8')

# %%
mat_ones.reshape(2073600)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], shape=(2073600,), dtype=uint8)

# %% [markdown]
# ---
# ## Tuplas

# %%
type(())
# Out:
# tuple

# %%
type((1, 2, 3))
# Out:
# tuple

# %%
type((1,))
# Out:
# tuple

# %% [markdown]
# * Qué es una matriz (Ana Domínguez)
# * Suma de matrices (Joshua Castro)
# * Resta de matrices (Nadia Villegas)
# * Multiplicación de matrices (Joss Carranza)
# * Producto de Hadamard (Abner)
# * Transpuesta de una matriz (Judith Puente)
