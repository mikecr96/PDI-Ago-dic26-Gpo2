# %% [markdown]
# ## f-string

# %%
print(r'C:\User\miguel\documentos')
# Out:
# C:\User\miguel\documentos

# %%
media = 127
mediana = 128
maximo = 255
minimo = 0

print('En esta imagen la media es: {}, la mediana es: {}, el máximo es: {} y el mínimo es: {}'.format(media, mediana, maximo, minimo))
# Out:
# En esta imagen la media es: 127, la mediana es: 128, el máximo es: 255 y el mínimo es: 0

# %%
print(f'En esta imagen la media es: {media}, la mediana es: {mediana}, el máximo es: {maximo} y el mínimo es: {minimo}')
# Out:
# En esta imagen la media es: 127, la mediana es: 128, el máximo es: 255 y el mínimo es: 0

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
for i in range(10):
    ruido = np.random.randint(256, size=(10, 10))
    plt.imshow(ruido, cmap='gray')
    plt.title(f'Figura #{i+1}')
    plt.show()

# %% [markdown]
# ---
# ## OpenCV

# %%
# %pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2 as cv

# %%
tralalero = cv.imread('/Users/miguelcamargorojas/Downloads/tralalero.avif')

# %%
type(tralalero)
# Out:
# numpy.ndarray

# %% [markdown]
# plt -> RGB
# cv  -> BGR

# %%
plt.imshow(tralalero[:, :, ::-1]) # La variable original sigue siendo BGR, para mostrar: RGB
plt.show()

# %%
# Separar los 3 canales de BGR

canal_b, canal_g, canal_r = cv.split(tralalero)

# %%
plt.imshow(np.hstack((tralalero, tralalero[:,:,::-1])))
plt.show()

# %%
# No se ejecuta imshow en cuadernos
# cv.imshow('Prueba', tralalero)
